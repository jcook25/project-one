# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

import warnings
warnings.filterwarnings('ignore')
import plotly as py
import plotly.graph_objs as go
import pandas as pd

from plotly.offline import init_notebook_mode, iplot # plotly offline mode
init_notebook_mode(connected=True) 

# File to Load (Remember to Change These)
d2015 = "Sheets/2015.csv"
d2016 = "Sheets/2016.csv"
d2017 = "Sheets/2017.csv"
d2018 = "Sheets/2018.csv"
d2019 = "Sheets/2019.csv"

# Read yearly data files
data_15 = pd.read_csv(d2015)
data_16 = pd.read_csv(d2016)
data_17 = pd.read_csv(d2017)
data_18 = pd.read_csv(d2018)
data_19 = pd.read_csv(d2019)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# year 2015 extract columns and rearrange columns

df15c = data_15.loc[:,['Happiness Rank', 'Country', 'Happiness Score', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Generosity',
       'Trust (Government Corruption)']]

#rename column
df15new= df15c.rename(columns={"Happiness Rank":"Overall rank",
                               "Country":"Country or region",
                               "Happiness Score":"Score",
                               "Economy (GDP per Capita)":"GDP per capita",
                               "Family":"Social support",
                               "Health (Life Expectancy)":"Healthy life expectancy",
                               "Freedom":"Freedom to make life choices",
                               "Generosity":"Generosity", 
                               "Trust (Government Corruption)": "Perceptions of corruption"})


df15new['Country or region'].replace(['Hong Kong S.A.R., China','Taiwan Province of China','Trinidad and Tobago','North Cyprus','Somaliland region'],['Hong Kong','Taiwan','Trinidad & Tobago','Northern Cyprus','Somaliland Region'], inplace = True)
df15new
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1       Switzerland  7.587         1.39651         1.34951
# 1               2           Iceland  7.561         1.30232         1.40223
# 2               3           Denmark  7.527         1.32548         1.36058
# 3               4            Norway  7.522         1.45900         1.33095
# 4               5            Canada  7.427         1.32629         1.32261
# ..            ...               ...    ...             ...             ...
# 153           154            Rwanda  3.465         0.22208         0.77370
# 154           155             Benin  3.340         0.28665         0.35386
# 155           156             Syria  3.006         0.66320         0.47489
# 156           157           Burundi  2.905         0.01530         0.41587
# 157           158              Togo  2.839         0.20868         0.13995
#
# ...

# %%
data_16.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
#year 2016 extract columns and rearrange columns

df16c = data_16.loc[:,['Happiness Rank', 'Country', 'Happiness Score', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Generosity',
       'Trust (Government Corruption)']]

#rename column
df16new = df16c.rename(columns={"Happiness Rank":"Overall rank", "Country":"Country or region","Happiness Score":"Score","Economy (GDP per Capita)":"GDP per capita", "Family":"Social support", "Health (Life Expectancy)":"Healthy life expectancy", "Freedom":"Freedom to make life choices", "Generosity":"Generosity", "Trust (Government Corruption)": "Perceptions of corruption"})

#replacing name change for HK and Taiwan
df16new['Country or region'].replace(['Hong Kong S.A.R., China','Taiwan Province of China','Trinidad and Tobago','North Cyprus','Somaliland region'],['Hong Kong','Taiwan','Trinidad & Tobago','Northern Cyprus','Somaliland Region'], inplace = True)
df16new
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1           Denmark  7.526         1.44178         1.16374
# 1               2       Switzerland  7.509         1.52733         1.14524
# 2               3           Iceland  7.501         1.42666         1.18326
# 3               4            Norway  7.498         1.57744         1.12690
# 4               5           Finland  7.413         1.40598         1.13464
# ..            ...               ...    ...             ...             ...
# 152           153             Benin  3.484         0.39499         0.10419
# 153           154       Afghanistan  3.360         0.38227         0.11037
# 154           155              Togo  3.303         0.28123         0.00000
# 155           156             Syria  3.069         0.74719         0.14866
# 156           157           Burundi  2.905         0.06831         0.23442
#
# ...

# %%
data_17.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
#year 2017 extract columns and rearrange columns

df17c = data_17.loc[:,['Happiness.Rank', 'Country', 'Happiness.Score', 'Economy..GDP.per.Capita.', 'Family',
       'Health..Life.Expectancy.', 'Freedom', 'Generosity',
       'Trust..Government.Corruption.']]

#rename column
df17new = df17c.rename(columns={"Happiness.Rank":"Overall rank", "Country":"Country or region","Happiness.Score":"Score","Economy..GDP.per.Capita.":"GDP per capita", "Family":"Social support", "Health..Life.Expectancy.":"Healthy life expectancy", "Freedom":"Freedom to make life choices", "Generosity":"Generosity", "Trust..Government.Corruption.": "Perceptions of corruption"})

#replacing name change for HK and Taiwan

df17new['Country or region'].replace(['Hong Kong S.A.R., China','Taiwan Province of China','Trinidad and Tobago','North Cyprus','Somaliland region'],['Hong Kong','Taiwan','Trinidad & Tobago','Northern Cyprus','Somaliland Region'], inplace = True)
df17new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                    Norway  7.537        1.616463
# 1               2                   Denmark  7.522        1.482383
# 2               3                   Iceland  7.504        1.480633
# 3               4               Switzerland  7.494        1.564980
# 4               5                   Finland  7.469        1.443572
# ..            ...                       ...    ...             ...
# 150           151                    Rwanda  3.471        0.368746
# 151           152                     Syria  3.462        0.777153
# 152           153                  Tanzania  3.349        0.511136
# 153           154                   Burundi  2.905        0.091623
# 154           155  Central African Republic  2.693        0.000000
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0          1.533524                 0.796667                      0.635423
# ...

# %%
df1516 = pd.merge(df15new, df16new, how="outer", on = "Country or region", suffixes=("_15", "_16"))
df1516
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 158              NaN       Puerto Rico       NaN                NaN
# 159              NaN            Belize       NaN                NaN
# 160              NaN           Somalia       NaN                NaN
# 161              NaN           Namibia       NaN                NaN
# 162              NaN       South Sudan       NaN                NaN
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# ...

# %%
df1718 = pd.merge(df17new, data_18, how="outer", on = "Country or region", suffixes=("_17", "_18"))
df1718
# Out:
#      Overall rank_17         Country or region  Score_17  GDP per capita_17  \
# 0                1.0                    Norway     7.537           1.616463
# 1                2.0                   Denmark     7.522           1.482383
# 2                3.0                   Iceland     7.504           1.480633
# 3                4.0               Switzerland     7.494           1.564980
# 4                5.0                   Finland     7.469           1.443572
# ..               ...                       ...       ...                ...
# 151            152.0                     Syria     3.462           0.777153
# 152            153.0                  Tanzania     3.349           0.511136
# 153            154.0                   Burundi     2.905           0.091623
# 154            155.0  Central African Republic     2.693           0.000000
# 155              NaN                      Laos       NaN                NaN
#
#      Social support_17  Healthy life expectancy_17  \
# ...

# %%
df17_19 = pd.merge(df1718, data_19, how="outer", on = "Country or region", suffixes=("", "_19"))
df17_19
# Out:
#      Overall rank_17 Country or region  Score_17  GDP per capita_17  \
# 0                1.0            Norway     7.537           1.616463
# 1                2.0           Denmark     7.522           1.482383
# 2                3.0           Iceland     7.504           1.480633
# 3                4.0       Switzerland     7.494           1.564980
# 4                5.0           Finland     7.469           1.443572
# ..               ...               ...       ...                ...
# 155              NaN              Laos       NaN                NaN
# 156              NaN   North Macedonia       NaN                NaN
# 157              NaN            Gambia       NaN                NaN
# 158              NaN         Swaziland       NaN                NaN
# 159              NaN           Comoros       NaN                NaN
#
#      Social support_17  Healthy life expectancy_17  \
# 0             1.533524                    0.796667
# ...

# %%
df_all= pd.merge(df1516, df17_19, how="outer", on = "Country or region", suffixes=("", ""))


df_all = df_all.rename(columns={"Overall rank":"Overall rank_19","Score":"Score_19","GDP per capita":"GDP per capita_19", "Social support":"Social support_19", "Healthy life expectancy":"Healthy life expectancy_19", "Freedom to make life choices":"Freedom to make life choices_19", "Generosity":"Generosity_19", "Perceptions of corruption": "Perceptions of corruption_19"})

df_all
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 160              NaN           Somalia       NaN                NaN
# 161              NaN           Namibia       NaN                NaN
# 162              NaN       South Sudan       NaN                NaN
# 163              NaN   North Macedonia       NaN                NaN
# 164              NaN            Gambia       NaN                NaN
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# ...

# %%
df_all.dropna(how='any',inplace=True)
df_all
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 153            154.0            Rwanda     3.465            0.22208
# 154            155.0             Benin     3.340            0.28665
# 155            156.0             Syria     3.006            0.66320
# 156            157.0           Burundi     2.905            0.01530
# 157            158.0              Togo     2.839            0.20868
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# ...

# %%
df_all.to_csv("Sheets/world_happiness.csv", index=False, header=True)

# %%
df_all['average_happiness_score_all'] = df_all[['Score_15', 'Score_16','Score_17', 'Score_18','Score_19']].mean(axis=1)
df_all
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 153            154.0            Rwanda     3.465            0.22208
# 154            155.0             Benin     3.340            0.28665
# 155            156.0             Syria     3.006            0.66320
# 156            157.0           Burundi     2.905            0.01530
# 157            158.0              Togo     2.839            0.20868
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# ...

# %%
df_all['average_rank_all'] = df_all[['Overall rank_15',
                                     'Overall rank_16',
                                     'Overall rank_17', 
                                     'Overall rank_18',
                                     'Overall rank_19']].mean(axis=1)

df_all['average_GDP_all'] = df_all[['GDP per capita_15',
                                     'GDP per capita_16',
                                     'GDP per capita_17', 
                                     'GDP per capita_18',
                                     'GDP per capita_19']].mean(axis=1)

df_all['average_social_all'] = df_all[['Social support_15',
                                     'Social support_16',
                                     'Social support_17', 
                                     'Social support_18',
                                     'Social support_19']].mean(axis=1)

df_all['average_health_all'] = df_all[['Healthy life expectancy_15',
                                     'Healthy life expectancy_16',
                                     'Healthy life expectancy_17', 
                                     'Healthy life expectancy_18',
                                     'Healthy life expectancy_19']].mean(axis=1)

df_all['average_freedom_all'] = df_all[['Freedom to make life choices_15',
                                     'Freedom to make life choices_16',
                                     'Freedom to make life choices_17', 
                                     'Freedom to make life choices_18',
                                     'Freedom to make life choices_19']].mean(axis=1)

df_all['average_generosity_all'] = df_all[['Generosity_15',
                                     'Generosity_16',
                                     'Generosity_17', 
                                     'Generosity_18',
                                     'Generosity_19']].mean(axis=1)

df_all['average_corruption_all'] = df_all[['Perceptions of corruption_15',
                                     'Perceptions of corruption_16',
                                     'Perceptions of corruption_17', 
                                     'Perceptions of corruption_18',
                                     'Perceptions of corruption_19']].mean(axis=1)
df_all
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 153            154.0            Rwanda     3.465            0.22208
# 154            155.0             Benin     3.340            0.28665
# 155            156.0             Syria     3.006            0.66320
# 156            157.0           Burundi     2.905            0.01530
# 157            158.0              Togo     2.839            0.20868
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# ...

# %%
df_all.to_csv("Sheets/world_happiness.csv", index=False, header=True)

# %%
df_all[['Country or region', 'average_GDP_all','average_happiness_score_all']].sort_values(by = 'average_GDP_all',
            ascending = False).head(10)
# Out:
#    Country or region  average_GDP_all  average_happiness_score_all
# 27             Qatar         1.743691                       6.4218
# 16        Luxembourg         1.637675                       6.9360
# 23         Singapore         1.592138                       6.5428
# 38            Kuwait         1.555662                       6.1486
# 3             Norway         1.519381                       7.5410
# 0        Switzerland         1.472164                       7.5114
# 17           Ireland         1.460415                       6.9644
# 71         Hong Kong         1.458283                       5.4528
# 14     United States         1.455946                       6.9988
# 34      Saudi Arabia         1.439513                       6.3760

# %%
happiness_score = df_all['average_happiness_score_all'].astype(float)

# %%
#installed plotly-3.10.0 in terminal
# as well as conda install -c conda-forge jupyterlab-plotly-extension

data = [dict(
        type='choropleth',
        colorscale = 'Blues',
        locations = df_all['Country or region'],
        z = happiness_score,
        locationmode = 'country names',
        text = df_all['Country or region'],
        colorbar = dict(
        title = 'Happiness Score', 
        titlefont=dict(size=25),
        tickfont=dict(size=18))
)]
layout = dict(
    title = 'Average Happiness Score',
    titlefont = dict(size=40),
    geo = dict(
        showframe = True,
        showcoastlines = True,
        projection = dict(type = 'equirectangular')
        )
)
choromap = go.Figure(data = data, layout = layout)
iplot(choromap, validate=False)
plt.savefig('Choromap 5 Year Average Happiness Score.png')
py.offline.plot(choromap)
# Out:
# <div>
#
#
#             <div id="e4ee2dd4-c429-4413-8579-5742b69ec5b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e4ee2dd4-c429-4413-8579-5742b69ec5b9")) {
#                     Plotly.newPlot(
#                         'e4ee2dd4-c429-4413-8579-5742b69ec5b9',
# ...

# %%
#compute the correlation matrix among the variables and plotted as heat map.

avg_matrix = df_all[['average_happiness_score_all','average_GDP_all','average_social_all','average_freedom_all', 
          'average_generosity_all','average_corruption_all']]
cor = avg_matrix.corr() 
plt.savefig('Matrix Happiness Score.png')
sns.heatmap(cor, annot = True, fmt= '.2f')
plt.rcParams['figure.figsize'] = [20.0, 7.0]
plt.title('Matrix Happiness Correlation')
plt.show()
#sns.heatmap(cor, square = True)

# %%
# Top ten happiness rank

df_all[['average_rank_all', 'Country or region',
        'average_happiness_score_all',
        'average_GDP_all',
        'average_social_all',
        'average_health_all',
        'average_freedom_all',
        'average_generosity_all',
        'average_corruption_all']].sort_values(by = 'average_rank_all',
            ascending = True).head(10)
# Out:
#    average_rank_all Country or region  average_happiness_score_all  \
# 2               2.2           Denmark                       7.5460
# 3               2.8            Norway                       7.5410
# 1               3.2           Iceland                       7.5110
# 0               3.6       Switzerland                       7.5114
# 5               3.6           Finland                       7.5378
# 6               6.2       Netherlands                       7.4046
# 4               6.8            Canada                       7.3506
# 8               8.2       New Zealand                       7.3130
# 7               8.6            Sweden                       7.3192
# 9              10.0         Australia                       7.2762
#
#    average_GDP_all  average_social_all  average_health_all  \
# 2         1.396729            1.447688            0.865249
# 3         1.519381            1.431075            0.873333
# ...

# %%
# Last ten happiness rank

df_all[['average_rank_all', 'Country or region',
        'average_happiness_score_all',
        'average_GDP_all',
        'average_social_all',
        'average_health_all',
        'average_freedom_all',
        'average_generosity_all',
        'average_corruption_all']].sort_values(by = 'average_rank_all',
            ascending = False).head(10)
# Out:
#      average_rank_all Country or region  average_happiness_score_all  \
# 156             153.8           Burundi                       3.0790
# 155             152.6             Syria                       3.2922
# 153             152.0            Rwanda                       3.4386
# 145             150.8          Tanzania                       3.4660
# 152             149.4       Afghanistan                       3.5128
# 157             148.2              Togo                       3.5442
# 135             146.4             Yemen                       3.6258
# 146             145.0        Madagascar                       3.7454
# 149             141.6            Guinea                       3.8536
# 115             140.8           Liberia                       3.8392
#
#      average_GDP_all  average_social_all  average_health_all  \
# 156         0.062447            0.470817            0.211608
# 155         0.699109            0.355931            0.566281
# ...

# %%
#scatter plots

xdata = df_all["average_GDP_all"]
# (slope,intercept,_,_,_) = stats.linregress("average_GDP_all","average_happiness_score_all")
ydata = df_all["average_happiness_score_all"] 

(slope,intercept,r,p,std) = stats.linregress(xdata,ydata)
fiteco = slope * xdata + intercept

df_all.plot(kind='scatter', x='average_GDP_all', y="average_happiness_score_all",alpha = 0.7,color = 'red')
plt.xlabel('Economy')              
plt.ylabel('Happiness')
plt.title('Economy with Happiness')
plt.plot(xdata, fiteco, "b--")
plt.savefig('Economy with Happiness Score.png')
print(slope)
print(intercept)
print(r)
print(p)
print(std)
plt.show()
# Out:
# 2.291984006089019
# 3.2807866689691343
# 0.8137484210954529
# 2.812441399189099e-35
# 0.1373775468217564

# %%
xdata = df_all["average_social_all"]
# (slope,intercept,_,_,_) = stats.linregress("average_GDP_all","average_happiness_score_all")
ydata = df_all["average_happiness_score_all"]

(slope,intercept,r,p,std) = stats.linregress(xdata,ydata)
fitfam = slope * xdata + intercept

df_all.plot(kind='scatter', x='average_social_all', y="average_happiness_score_all",alpha = 0.5,color = 'blue')
plt.xlabel('Social Support')              
plt.ylabel('Happiness')
plt.title('Social Support with Happiness')
plt.plot(xdata, fitfam, "Y")
plt.savefig('Social Support Happinessn Score.png')
print(f'slope: {slope}')
print(f'intercept: {intercept}')
print(f'r-value: {r}')
print(f'p-value: {p}')
print(f'std error: {std}')
plt.show()
# Out:
# slope: 3.2081245304596706
# intercept: 1.91563721812715
# r-value: 0.7865198665978202
# p-value: 1.601101288815014e-31
# std error: 0.21138784276061795

# %%
xdata = df_all["average_health_all"]
# (slope,intercept,_,_,_) = stats.linregress("average_GDP_all","average_happiness_score_all")
ydata = df_all["average_happiness_score_all"]

(slope,intercept,r,p,std) = stats.linregress(xdata,ydata)
fithealth = slope * xdata + intercept

df_all.plot(kind='scatter', x='average_health_all', y="average_happiness_score_all",alpha = 0.7,color = 'black')
plt.xlabel('Healthy life expectancy')              
plt.ylabel('Happiness')
plt.title('Healthy life expectancy with Happiness')
plt.plot(xdata, fithealth, "G")
plt.savefig('Health Life Expectancy Happiness Score.png')
print(f'slope: {slope}')
print(f'intercept: {intercept}')
print(f'r-value: {r}')
print(f'p-value: {p}')
print(f'std error: {std}')
plt.show()
# Out:
# slope: 3.8144325692734036
# intercept: 3.01294878567647
# r-value: 0.7818673398924544
# p-value: 6.184741179404112e-31
# std error: 0.2552411714416638

# %%
xdata = df_all["average_freedom_all"]
# (slope,intercept,_,_,_) = stats.linregress("average_GDP_all","average_happiness_score_all")
ydata = df_all["average_happiness_score_all"]

(slope,intercept,r,p,std) = stats.linregress(xdata,ydata)
fitfree = slope * xdata + intercept

df_all.plot(kind='scatter', x='average_freedom_all', y="average_happiness_score_all",alpha = 0.7,color = 'teal')
plt.xlabel('Freedom to make life choices')              
plt.ylabel('Happiness')
plt.title('Freedom to make life choices with Happiness')
plt.plot(xdata, fitfree, "black")
plt.savefig('Freedom to make life choice with Happiness Score.png')
print(f'slope: {slope}')
print(f'intercept: {intercept}')
print(f'r-value: {r}')
print(f'p-value: {p}')
print(f'std error: {std}')
plt.show()
# Out:
# slope: 4.57565401293278
# intercept: 3.53644861236884
# r-value: 0.580560905048867
# p-value: 2.401756082308835e-14
# std error: 0.5385193218406932

# %%
xdata = df_all["average_generosity_all"]
# (slope,intercept,_,_,_) = stats.linregress("average_GDP_all","average_happiness_score_all")
ydata = df_all["average_happiness_score_all"]

(slope,intercept,r,p,std) = stats.linregress(xdata,ydata)
fitgen = slope * xdata + intercept

df_all.plot(kind='scatter', x='average_generosity_all', y="average_happiness_score_all",alpha = 0.7,color = 'brown')
plt.xlabel('Generosity')              
plt.ylabel('Happiness')
plt.title('Generosity with Happiness')
plt.plot(xdata, fitgen, "black")
plt.savefig('Generosityvwith Happiness Score.png')
print(f'slope: {slope}')
print(f'intercept: {intercept}')
print(f'r-value: {r}')
print(f'p-value: {p}')
print(f'std error: {std}')
plt.show()
# Out:
# slope: 1.42319936478116
# intercept: 5.121657062991089
# r-value: 0.15188913675812032
# p-value: 0.06916453087951552
# std error: 0.7771887571878462

# %%
xdata = df_all["average_corruption_all"]
# (slope,intercept,_,_,_) = stats.linregress("average_GDP_all","average_happiness_score_all")
ydata = df_all["average_happiness_score_all"]

(slope,intercept,r,p,std) = stats.linregress(xdata,ydata)
fitcor = slope * xdata + intercept

df_all.plot(kind='scatter', x='average_corruption_all', y="average_happiness_score_all",alpha = 0.7,color = 'pink')
plt.xlabel('Perceptions of corruption')              
plt.ylabel('Happiness')
plt.title('Perceptions of corruption with Happiness')
plt.plot(xdata, fitcor, "teal")
plt.savefig('Perception of Corruption with Happiness.png')
print(f'slope: {slope}')
print(f'intercept: {intercept}')
print(f'r-value: {r}')
print(f'p-value: {p}')
print(f'std error: {std}')
plt.show()
# Out:
# slope: 4.676538805562874
# intercept: 4.85564717272285
# r-value: 0.435311592068919
# p-value: 4.963306280867068e-08
# std error: 0.8116292133379833

# %%
sns.barplot(x = df_all['Country or region'].head(10), y = df_all['average_happiness_score_all'])
plt.title('Top Ten Countries Happiness Score')
plt.show()
plt.savefig('Top Ten Countries Happiness Score.png')


sns.barplot(x = df_all['Country or region'].tail(10), y = df_all['average_happiness_score_all'])
plt.title('Last Ten Countries Happiness Score')
plt.show()
plt.savefig('Last Ten Countries Happiness Score.png')
