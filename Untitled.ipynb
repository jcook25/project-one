# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
d2015 = "Sheets/2015.csv"
d2016 = "Sheets/2016.csv"
d2017 = "Sheets/2017.csv"
d2018 = "Sheets/2018.csv"

# Read School and Student Data File and store into Pandas Data Frames
data_15 = pd.read_csv(d2015)
data_16 = pd.read_csv(d2016)
data_17 = pd.read_csv(d2017)

# Combine the data into a single dataset
df1516 = pd.merge(data_15, data_16, how="inner", on=["Country", "Country"], suffixes=("_15", "_16"))

# %%
df1516
# Out:
#          Country                        Region_15  Happiness Rank_15  \
# 0    Switzerland                   Western Europe                  1
# 1        Iceland                   Western Europe                  2
# 2        Denmark                   Western Europe                  3
# 3         Norway                   Western Europe                  4
# 4         Canada                    North America                  5
# ..           ...                              ...                ...
# 146       Rwanda               Sub-Saharan Africa                154
# 147        Benin               Sub-Saharan Africa                155
# 148        Syria  Middle East and Northern Africa                156
# 149      Burundi               Sub-Saharan Africa                157
# 150         Togo               Sub-Saharan Africa                158
#
#      Happiness Score_15  Standard Error  Economy (GDP per Capita)_15  \
# 0                 7.587         0.03411                      1.39651
# 1                 7.561         0.04884                      1.30232
# 2                 7.527         0.03328                      1.32548
# 3                 7.522         0.03880                      1.45900
# 4                 7.427         0.03553                      1.32629
# ..                  ...             ...                          ...
# 146               3.465         0.03464                      0.22208
# 147               3.340         0.03656                      0.28665
# 148               3.006         0.05015                      0.66320
# 149               2.905         0.08658                      0.01530
# 150               2.839         0.06727                      0.20868
#
#      Family_15  Health (Life Expectancy)_15  Freedom_15  \
# 0      1.34951                      0.94143     0.66557
# 1      1.40223                      0.94784     0.62877
# 2      1.36058                      0.87464     0.64938
# 3      1.33095                      0.88521     0.66973
# 4      1.32261                      0.90563     0.63297
# ..         ...                          ...         ...
# 146    0.77370                      0.42864     0.59201
# 147    0.35386                      0.31910     0.48450
# 148    0.47489                      0.72193     0.15684
# 149    0.41587                      0.22396     0.11850
# 150    0.13995                      0.28443     0.36453
#
#      Trust (Government Corruption)_15  ...  Happiness Score_16  \
# 0                             0.41978  ...               7.509
# 1                             0.14145  ...               7.501
# 2                             0.48357  ...               7.526
# 3                             0.36503  ...               7.498
# 4                             0.32957  ...               7.404
# ..                                ...  ...                 ...
# 146                           0.55191  ...               3.515
# 147                           0.08010  ...               3.484
# 148                           0.18906  ...               3.069
# 149                           0.10062  ...               2.905
# 150                           0.10731  ...               3.303
#
#      Lower Confidence Interval Upper Confidence Interval  \
# 0                        7.428                     7.590
# 1                        7.333                     7.669
# 2                        7.460                     7.592
# 3                        7.421                     7.575
# 4                        7.335                     7.473
# ..                         ...                       ...
# 146                      3.444                     3.586
# 147                      3.404                     3.564
# 148                      2.936                     3.202
# 149                      2.732                     3.078
# 150                      3.192                     3.414
#
#      Economy (GDP per Capita)_16  Family_16  Health (Life Expectancy)_16  \
# 0                        1.52733    1.14524                      0.86303
# 1                        1.42666    1.18326                      0.86733
# 2                        1.44178    1.16374                      0.79504
# 3                        1.57744    1.12690                      0.79579
# 4                        1.44015    1.09610                      0.82760
# ..                           ...        ...                          ...
# 146                      0.32846    0.61586                      0.31865
# 147                      0.39499    0.10419                      0.21028
# 148                      0.74719    0.14866                      0.62994
# 149                      0.06831    0.23442                      0.15747
# 150                      0.28123    0.00000                      0.24811
#
#      Freedom_16  Trust (Government Corruption)_16  Generosity_16  \
# 0       0.58557                           0.41203        0.28083
# 1       0.56624                           0.14975        0.47678
# 2       0.57941                           0.44453        0.36171
# 3       0.59609                           0.35776        0.37895
# 4       0.57370                           0.31329        0.44834
# ..          ...                               ...            ...
# 146     0.54320                           0.50521        0.23552
# 147     0.39747                           0.06681        0.20180
# 148     0.06912                           0.17233        0.48397
# 149     0.04320                           0.09419        0.20290
# 150     0.34678                           0.11587        0.17517
#
#      Dystopia Residual_16
# 0                 2.69463
# 1                 2.83137
# 2                 2.73939
# 3                 2.66465
# 4                 2.70485
# ..                    ...
# 146               0.96819
# 147               2.10812
# 148               0.81789
# 149               2.10404
# 150               2.13540
#
# [151 rows x 24 columns]

# %%
data_15.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df15c = data_15[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity']]

# %%
# Export file as a CSV, without the Pandas index, but with the header
df15c.to_csv("Sheets/15c.csv", index=False, header=True)
