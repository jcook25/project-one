# %%
# Dependencies and Setup
import pandas as pd

# Files
d15 = "Sheets/2015.csv"
d16 = "Sheets/2016.csv"
d17 = "Sheets/2017.csv"
d18 = "Sheets/2018.csv"
d19 = "Sheets/2019.csv"

# Read
data_15 = pd.read_csv(d15)
data_16 = pd.read_csv(d16)
data_17 = pd.read_csv(d17)
data_18 = pd.read_csv(d18)

# Combine the data into a single dataset
df1516 = pd.merge(data_15, data_16, how="outer", on=["Country", "Country"], suffixes=("_15", "_16"))
df1516.head()
# Out:
#        Country       Region_15  Happiness Rank_15  Happiness Score_15  \
# 0  Switzerland  Western Europe                1.0               7.587
# 1      Iceland  Western Europe                2.0               7.561
# 2      Denmark  Western Europe                3.0               7.527
# 3       Norway  Western Europe                4.0               7.522
# 4       Canada   North America                5.0               7.427
#
#    Standard Error  Economy (GDP per Capita)_15  Family_15  \
# 0         0.03411                      1.39651    1.34951
# 1         0.04884                      1.30232    1.40223
# 2         0.03328                      1.32548    1.36058
# 3         0.03880                      1.45900    1.33095
# 4         0.03553                      1.32629    1.32261
#
#    Health (Life Expectancy)_15  Freedom_15  Trust (Government Corruption)_15  \
# 0                      0.94143     0.66557                           0.41978
# ...

# %%
df1718 = pd.merge(data_17, data_18, how="outer", on=["Country", "Country or region"], suffixes=("_17", "_18"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-360202cfa11a> in <module>
# ----> 1 df1718 = pd.merge(data_17, data_18, how="outer", on=["Country", "Country or region"], suffixes=("_17", "_18"))
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     624             self.right_join_keys,
#     625             self.join_names,
# --> 626         ) = self._get_merge_keys()
#     627
# ...

# %%
df1516.head()

# %%
data_15.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df15c = data_15[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity']]

# %%
# Export file as a CSV, without the Pandas index, but with the header
df15c.to_csv("Sheets/15c.csv", index=False, header=True)
