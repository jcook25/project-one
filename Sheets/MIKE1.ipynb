# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

import warnings
warnings.filterwarnings('ignore')
import plotly as py
import plotly.express as px

from plotly.offline import init_notebook_mode, iplot # plotly offline mode
init_notebook_mode(connected=True) 

# File to Load (Remember to Change These)
d2015 = "2015.csv"
d2016 = "2016.csv"
d2017 = "2017.csv"
d2018 = "2018.csv"
d2019 = "2019.csv"

# Read yearly data files
data_15 = pd.read_csv(d2015)
data_16 = pd.read_csv(d2016)
data_17 = pd.read_csv(d2017)
data_18 = pd.read_csv(d2018)
data_19 = pd.read_csv(d2019)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# year 2015 extract columns and rearrange columns

df15c = data_15.loc[:,['Happiness Rank', 'Country', 'Happiness Score', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Generosity',
       'Trust (Government Corruption)']]

#rename column
df15new= df15c.rename(columns={"Happiness Rank":"Overall rank",
                               "Country":"Country or region",
                               "Happiness Score":"Score",
                               "Economy (GDP per Capita)":"GDP per capita",
                               "Family":"Social support",
                               "Health (Life Expectancy)":"Healthy life expectancy",
                               "Freedom":"Freedom to make life choices",
                               "Generosity":"Generosity", 
                               "Trust (Government Corruption)": "Perceptions of corruption"})


df15new['Country or region'].replace(['Hong Kong S.A.R., China','Taiwan Province of China','Trinidad and Tobago','North Cyprus','Somaliland region'],['Hong Kong','Taiwan','Trinidad & Tobago','Northern Cyprus','Somaliland Region'], inplace = True)
df15new
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1       Switzerland  7.587         1.39651         1.34951
# 1               2           Iceland  7.561         1.30232         1.40223
# 2               3           Denmark  7.527         1.32548         1.36058
# 3               4            Norway  7.522         1.45900         1.33095
# 4               5            Canada  7.427         1.32629         1.32261
# ..            ...               ...    ...             ...             ...
# 153           154            Rwanda  3.465         0.22208         0.77370
# 154           155             Benin  3.340         0.28665         0.35386
# 155           156             Syria  3.006         0.66320         0.47489
# 156           157           Burundi  2.905         0.01530         0.41587
# 157           158              Togo  2.839         0.20868         0.13995
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.94143                       0.66557     0.29678
# 1                    0.94784                       0.62877     0.43630
# 2                    0.87464                       0.64938     0.34139
# 3                    0.88521                       0.66973     0.34699
# 4                    0.90563                       0.63297     0.45811
# ..                       ...                           ...         ...
# 153                  0.42864                       0.59201     0.22628
# 154                  0.31910                       0.48450     0.18260
# 155                  0.72193                       0.15684     0.47179
# 156                  0.22396                       0.11850     0.19727
# 157                  0.28443                       0.36453     0.16681
#
#      Perceptions of corruption
# 0                      0.41978
# 1                      0.14145
# 2                      0.48357
# 3                      0.36503
# 4                      0.32957
# ..                         ...
# 153                    0.55191
# 154                    0.08010
# 155                    0.18906
# 156                    0.10062
# 157                    0.10731
#
# [158 rows x 9 columns]

# %%
df15new.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
data_16.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
#year 2016 extract columns and rearrange columns

df16c = data_16.loc[:,['Happiness Rank', 'Country', 'Happiness Score', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Generosity',
       'Trust (Government Corruption)']]

#rename column
df16new = df16c.rename(columns={"Happiness Rank":"Overall rank", "Country":"Country or region","Happiness Score":"Score","Economy (GDP per Capita)":"GDP per capita", "Family":"Social support", "Health (Life Expectancy)":"Healthy life expectancy", "Freedom":"Freedom to make life choices", "Generosity":"Generosity", "Trust (Government Corruption)": "Perceptions of corruption"})

#replacing name change for HK and Taiwan
df16new['Country or region'].replace(['Hong Kong S.A.R., China','Taiwan Province of China','Trinidad and Tobago','North Cyprus','Somaliland region'],['Hong Kong','Taiwan','Trinidad & Tobago','Northern Cyprus','Somaliland Region'], inplace = True)
df16new
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1           Denmark  7.526         1.44178         1.16374
# 1               2       Switzerland  7.509         1.52733         1.14524
# 2               3           Iceland  7.501         1.42666         1.18326
# 3               4            Norway  7.498         1.57744         1.12690
# 4               5           Finland  7.413         1.40598         1.13464
# ..            ...               ...    ...             ...             ...
# 152           153             Benin  3.484         0.39499         0.10419
# 153           154       Afghanistan  3.360         0.38227         0.11037
# 154           155              Togo  3.303         0.28123         0.00000
# 155           156             Syria  3.069         0.74719         0.14866
# 156           157           Burundi  2.905         0.06831         0.23442
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.79504                       0.57941     0.36171
# 1                    0.86303                       0.58557     0.28083
# 2                    0.86733                       0.56624     0.47678
# 3                    0.79579                       0.59609     0.37895
# 4                    0.81091                       0.57104     0.25492
# ..                       ...                           ...         ...
# 152                  0.21028                       0.39747     0.20180
# 153                  0.17344                       0.16430     0.31268
# 154                  0.24811                       0.34678     0.17517
# 155                  0.62994                       0.06912     0.48397
# 156                  0.15747                       0.04320     0.20290
#
#      Perceptions of corruption
# 0                      0.44453
# 1                      0.41203
# 2                      0.14975
# 3                      0.35776
# 4                      0.41004
# ..                         ...
# 152                    0.06681
# 153                    0.07112
# 154                    0.11587
# 155                    0.17233
# 156                    0.09419
#
# [157 rows x 9 columns]

# %%
data_17.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
#year 2017 extract columns and rearrange columns

df17c = data_17.loc[:,['Happiness.Rank', 'Country', 'Happiness.Score', 'Economy..GDP.per.Capita.', 'Family',
       'Health..Life.Expectancy.', 'Freedom', 'Generosity',
       'Trust..Government.Corruption.']]

#rename column
df17new = df17c.rename(columns={"Happiness.Rank":"Overall rank", "Country":"Country or region","Happiness.Score":"Score","Economy..GDP.per.Capita.":"GDP per capita", "Family":"Social support", "Health..Life.Expectancy.":"Healthy life expectancy", "Freedom":"Freedom to make life choices", "Generosity":"Generosity", "Trust..Government.Corruption.": "Perceptions of corruption"})

#replacing name change for HK and Taiwan

df17new['Country or region'].replace(['Hong Kong S.A.R., China','Taiwan Province of China','Trinidad and Tobago','North Cyprus','Somaliland region'],['Hong Kong','Taiwan','Trinidad & Tobago','Northern Cyprus','Somaliland Region'], inplace = True)
df17new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                    Norway  7.537        1.616463
# 1               2                   Denmark  7.522        1.482383
# 2               3                   Iceland  7.504        1.480633
# 3               4               Switzerland  7.494        1.564980
# 4               5                   Finland  7.469        1.443572
# ..            ...                       ...    ...             ...
# 150           151                    Rwanda  3.471        0.368746
# 151           152                     Syria  3.462        0.777153
# 152           153                  Tanzania  3.349        0.511136
# 153           154                   Burundi  2.905        0.091623
# 154           155  Central African Republic  2.693        0.000000
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0          1.533524                 0.796667                      0.635423
# 1          1.551122                 0.792566                      0.626007
# 2          1.610574                 0.833552                      0.627163
# 3          1.516912                 0.858131                      0.620071
# 4          1.540247                 0.809158                      0.617951
# ..              ...                      ...                           ...
# 150        0.945707                 0.326425                      0.581844
# 151        0.396103                 0.500533                      0.081539
# 152        1.041990                 0.364509                      0.390018
# 153        0.629794                 0.151611                      0.059901
# 154        0.000000                 0.018773                      0.270842
#
#      Generosity  Perceptions of corruption
# 0      0.362012                   0.315964
# 1      0.355280                   0.400770
# 2      0.475540                   0.153527
# 3      0.290549                   0.367007
# 4      0.245483                   0.382612
# ..          ...                        ...
# 150    0.252756                   0.455220
# 151    0.493664                   0.151347
# 152    0.354256                   0.066035
# 153    0.204435                   0.084148
# 154    0.280876                   0.056565
#
# [155 rows x 9 columns]

# %%
df1516 = pd.merge(df15new, df16new, how="outer", on = "Country or region", suffixes=("_15", "_16"))
df1516
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 158              NaN       Puerto Rico       NaN                NaN
# 159              NaN            Belize       NaN                NaN
# 160              NaN           Somalia       NaN                NaN
# 161              NaN           Namibia       NaN                NaN
# 162              NaN       South Sudan       NaN                NaN
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# 1              1.40223                     0.94784
# 2              1.36058                     0.87464
# 3              1.33095                     0.88521
# 4              1.32261                     0.90563
# ..                 ...                         ...
# 158                NaN                         NaN
# 159                NaN                         NaN
# 160                NaN                         NaN
# 161                NaN                         NaN
# 162                NaN                         NaN
#
#      Freedom to make life choices_15  Generosity_15  \
# 0                            0.66557        0.29678
# 1                            0.62877        0.43630
# 2                            0.64938        0.34139
# 3                            0.66973        0.34699
# 4                            0.63297        0.45811
# ..                               ...            ...
# 158                              NaN            NaN
# 159                              NaN            NaN
# 160                              NaN            NaN
# 161                              NaN            NaN
# 162                              NaN            NaN
#
#      Perceptions of corruption_15  Overall rank_16  Score_16  \
# 0                         0.41978              2.0     7.509
# 1                         0.14145              3.0     7.501
# 2                         0.48357              1.0     7.526
# 3                         0.36503              4.0     7.498
# 4                         0.32957              6.0     7.404
# ..                            ...              ...       ...
# 158                           NaN             15.0     7.039
# 159                           NaN             52.0     5.956
# 160                           NaN             76.0     5.440
# 161                           NaN            113.0     4.574
# 162                           NaN            143.0     3.832
#
#      GDP per capita_16  Social support_16  Healthy life expectancy_16  \
# 0              1.52733            1.14524                     0.86303
# 1              1.42666            1.18326                     0.86733
# 2              1.44178            1.16374                     0.79504
# 3              1.57744            1.12690                     0.79579
# 4              1.44015            1.09610                     0.82760
# ..                 ...                ...                         ...
# 158            1.35943            1.08113                     0.77758
# 159            0.87616            0.68655                     0.45569
# 160            0.00000            0.33613                     0.11466
# 161            0.93287            0.70362                     0.34745
# 162            0.39394            0.18519                     0.15781
#
#      Freedom to make life choices_16  Generosity_16  \
# 0                            0.58557        0.28083
# 1                            0.56624        0.47678
# 2                            0.57941        0.36171
# 3                            0.59609        0.37895
# 4                            0.57370        0.44834
# ..                               ...            ...
# 158                          0.46823        0.22202
# 159                          0.51231        0.23684
# 160                          0.56778        0.27225
# 161                          0.48614        0.07795
# 162                          0.19662        0.25899
#
#      Perceptions of corruption_16
# 0                         0.41203
# 1                         0.14975
# 2                         0.44453
# 3                         0.35776
# 4                         0.31329
# ..                            ...
# 158                       0.12275
# 159                       0.10771
# 160                       0.31180
# 161                       0.10398
# 162                       0.13015
#
# [163 rows x 17 columns]

# %%
df1718 = pd.merge(df17new, data_18, how="outer", on = "Country or region", suffixes=("_17", "_18"))
df1718
# Out:
#      Overall rank_17         Country or region  Score_17  GDP per capita_17  \
# 0                1.0                    Norway     7.537           1.616463
# 1                2.0                   Denmark     7.522           1.482383
# 2                3.0                   Iceland     7.504           1.480633
# 3                4.0               Switzerland     7.494           1.564980
# 4                5.0                   Finland     7.469           1.443572
# ..               ...                       ...       ...                ...
# 151            152.0                     Syria     3.462           0.777153
# 152            153.0                  Tanzania     3.349           0.511136
# 153            154.0                   Burundi     2.905           0.091623
# 154            155.0  Central African Republic     2.693           0.000000
# 155              NaN                      Laos       NaN                NaN
#
#      Social support_17  Healthy life expectancy_17  \
# 0             1.533524                    0.796667
# 1             1.551122                    0.792566
# 2             1.610574                    0.833552
# 3             1.516912                    0.858131
# 4             1.540247                    0.809158
# ..                 ...                         ...
# 151           0.396103                    0.500533
# 152           1.041990                    0.364509
# 153           0.629794                    0.151611
# 154           0.000000                    0.018773
# 155                NaN                         NaN
#
#      Freedom to make life choices_17  Generosity_17  \
# 0                           0.635423       0.362012
# 1                           0.626007       0.355280
# 2                           0.627163       0.475540
# 3                           0.620071       0.290549
# 4                           0.617951       0.245483
# ..                               ...            ...
# 151                         0.081539       0.493664
# 152                         0.390018       0.354256
# 153                         0.059901       0.204435
# 154                         0.270842       0.280876
# 155                              NaN            NaN
#
#      Perceptions of corruption_17  Overall rank_18  Score_18  \
# 0                        0.315964                2     7.594
# 1                        0.400770                3     7.555
# 2                        0.153527                4     7.495
# 3                        0.367007                5     7.487
# 4                        0.382612                1     7.632
# ..                            ...              ...       ...
# 151                      0.151347              150     3.462
# 152                      0.066035              153     3.303
# 153                      0.084148              156     2.905
# 154                      0.056565              155     3.083
# 155                           NaN              110     4.623
#
#      GDP per capita_18  Social support_18  Healthy life expectancy_18  \
# 0                1.456              1.582                       0.861
# 1                1.351              1.590                       0.868
# 2                1.343              1.644                       0.914
# 3                1.420              1.549                       0.927
# 4                1.305              1.592                       0.874
# ..                 ...                ...                         ...
# 151              0.689              0.382                       0.539
# 152              0.455              0.991                       0.381
# 153              0.091              0.627                       0.145
# 154              0.024              0.000                       0.010
# 155              0.720              1.034                       0.441
#
#      Freedom to make life choices_18  Generosity_18  \
# 0                              0.686          0.286
# 1                              0.683          0.284
# 2                              0.677          0.353
# 3                              0.660          0.256
# 4                              0.681          0.202
# ..                               ...            ...
# 151                            0.088          0.376
# 152                            0.481          0.270
# 153                            0.065          0.149
# 154                            0.305          0.218
# 155                            0.626          0.230
#
#      Perceptions of corruption_18
# 0                           0.340
# 1                           0.408
# 2                           0.138
# 3                           0.357
# 4                           0.393
# ..                            ...
# 151                         0.144
# 152                         0.097
# 153                         0.076
# 154                         0.038
# 155                         0.174
#
# [156 rows x 17 columns]

# %%
df17_19 = pd.merge(df1718, data_19, how="outer", on = "Country or region", suffixes=("", "_19"))
df17_19
# Out:
#      Overall rank_17 Country or region  Score_17  GDP per capita_17  \
# 0                1.0            Norway     7.537           1.616463
# 1                2.0           Denmark     7.522           1.482383
# 2                3.0           Iceland     7.504           1.480633
# 3                4.0       Switzerland     7.494           1.564980
# 4                5.0           Finland     7.469           1.443572
# ..               ...               ...       ...                ...
# 155              NaN              Laos       NaN                NaN
# 156              NaN   North Macedonia       NaN                NaN
# 157              NaN            Gambia       NaN                NaN
# 158              NaN         Swaziland       NaN                NaN
# 159              NaN           Comoros       NaN                NaN
#
#      Social support_17  Healthy life expectancy_17  \
# 0             1.533524                    0.796667
# 1             1.551122                    0.792566
# 2             1.610574                    0.833552
# 3             1.516912                    0.858131
# 4             1.540247                    0.809158
# ..                 ...                         ...
# 155                NaN                         NaN
# 156                NaN                         NaN
# 157                NaN                         NaN
# 158                NaN                         NaN
# 159                NaN                         NaN
#
#      Freedom to make life choices_17  Generosity_17  \
# 0                           0.635423       0.362012
# 1                           0.626007       0.355280
# 2                           0.627163       0.475540
# 3                           0.620071       0.290549
# 4                           0.617951       0.245483
# ..                               ...            ...
# 155                              NaN            NaN
# 156                              NaN            NaN
# 157                              NaN            NaN
# 158                              NaN            NaN
# 159                              NaN            NaN
#
#      Perceptions of corruption_17  Overall rank_18  ...  Generosity_18  \
# 0                        0.315964              2.0  ...          0.286
# 1                        0.400770              3.0  ...          0.284
# 2                        0.153527              4.0  ...          0.353
# 3                        0.367007              5.0  ...          0.256
# 4                        0.382612              1.0  ...          0.202
# ..                            ...              ...  ...            ...
# 155                           NaN            110.0  ...          0.230
# 156                           NaN              NaN  ...            NaN
# 157                           NaN              NaN  ...            NaN
# 158                           NaN              NaN  ...            NaN
# 159                           NaN              NaN  ...            NaN
#
#      Perceptions of corruption_18  Overall rank  Score  GDP per capita  \
# 0                           0.340           3.0  7.554           1.488
# 1                           0.408           2.0  7.600           1.383
# 2                           0.138           4.0  7.494           1.380
# 3                           0.357           6.0  7.480           1.452
# 4                           0.393           1.0  7.769           1.340
# ..                            ...           ...    ...             ...
# 155                         0.174         105.0  4.796           0.764
# 156                           NaN          84.0  5.274           0.983
# 157                           NaN         120.0  4.516           0.308
# 158                           NaN         135.0  4.212           0.811
# 159                           NaN         142.0  3.973           0.274
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.582                    1.028                         0.603
# 1             1.573                    0.996                         0.592
# 2             1.624                    1.026                         0.591
# 3             1.526                    1.052                         0.572
# 4             1.587                    0.986                         0.596
# ..              ...                      ...                           ...
# 155           1.030                    0.551                         0.547
# 156           1.294                    0.838                         0.345
# 157           0.939                    0.428                         0.382
# 158           1.149                    0.000                         0.313
# 159           0.757                    0.505                         0.142
#
#      Generosity  Perceptions of corruption
# 0         0.271                      0.341
# 1         0.252                      0.410
# 2         0.354                      0.118
# 3         0.263                      0.343
# 4         0.153                      0.393
# ..          ...                        ...
# 155       0.266                      0.164
# 156       0.185                      0.034
# 157       0.269                      0.167
# 158       0.074                      0.135
# 159       0.275                      0.078
#
# [160 rows x 25 columns]

# %%
df_all= pd.merge(df1516, df17_19, how="outer", on = "Country or region", suffixes=("", ""))


df_all = df_all.rename(columns={"Overall rank":"Overall rank_19","Score":"Score_19","GDP per capita":"GDP per capita_19", "Social support":"Social support_19", "Healthy life expectancy":"Healthy life expectancy_19", "Freedom to make life choices":"Freedom to make life choices_19", "Generosity":"Generosity_19", "Perceptions of corruption": "Perceptions of corruption_19"})

df_all
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 160              NaN           Somalia       NaN                NaN
# 161              NaN           Namibia       NaN                NaN
# 162              NaN       South Sudan       NaN                NaN
# 163              NaN   North Macedonia       NaN                NaN
# 164              NaN            Gambia       NaN                NaN
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# 1              1.40223                     0.94784
# 2              1.36058                     0.87464
# 3              1.33095                     0.88521
# 4              1.32261                     0.90563
# ..                 ...                         ...
# 160                NaN                         NaN
# 161                NaN                         NaN
# 162                NaN                         NaN
# 163                NaN                         NaN
# 164                NaN                         NaN
#
#      Freedom to make life choices_15  Generosity_15  \
# 0                            0.66557        0.29678
# 1                            0.62877        0.43630
# 2                            0.64938        0.34139
# 3                            0.66973        0.34699
# 4                            0.63297        0.45811
# ..                               ...            ...
# 160                              NaN            NaN
# 161                              NaN            NaN
# 162                              NaN            NaN
# 163                              NaN            NaN
# 164                              NaN            NaN
#
#      Perceptions of corruption_15  Overall rank_16  ...  Generosity_18  \
# 0                         0.41978              2.0  ...          0.256
# 1                         0.14145              3.0  ...          0.353
# 2                         0.48357              1.0  ...          0.284
# 3                         0.36503              4.0  ...          0.286
# 4                         0.32957              6.0  ...          0.321
# ..                            ...              ...  ...            ...
# 160                           NaN             76.0  ...          0.238
# 161                           NaN            113.0  ...          0.051
# 162                           NaN            143.0  ...          0.224
# 163                           NaN              NaN  ...            NaN
# 164                           NaN              NaN  ...            NaN
#
#      Perceptions of corruption_18  Overall rank_19  Score_19  \
# 0                           0.357              6.0     7.480
# 1                           0.138              4.0     7.494
# 2                           0.408              2.0     7.600
# 3                           0.340              3.0     7.554
# 4                           0.291              9.0     7.278
# ..                            ...              ...       ...
# 160                         0.282            112.0     4.668
# 161                         0.064            113.0     4.639
# 162                         0.106            156.0     2.853
# 163                           NaN             84.0     5.274
# 164                           NaN            120.0     4.516
#
#      GDP per capita_19  Social support_19  Healthy life expectancy_19  \
# 0                1.452              1.526                       1.052
# 1                1.380              1.624                       1.026
# 2                1.383              1.573                       0.996
# 3                1.488              1.582                       1.028
# 4                1.365              1.505                       1.039
# ..                 ...                ...                         ...
# 160              0.000              0.698                       0.268
# 161              0.879              1.313                       0.477
# 162              0.306              0.575                       0.295
# 163              0.983              1.294                       0.838
# 164              0.308              0.939                       0.428
#
#      Freedom to make life choices_19  Generosity_19  \
# 0                              0.572          0.263
# 1                              0.591          0.354
# 2                              0.592          0.252
# 3                              0.603          0.271
# 4                              0.584          0.285
# ..                               ...            ...
# 160                            0.559          0.243
# 161                            0.401          0.070
# 162                            0.010          0.202
# 163                            0.345          0.185
# 164                            0.382          0.269
#
#      Perceptions of corruption_19
# 0                           0.343
# 1                           0.118
# 2                           0.410
# 3                           0.341
# 4                           0.308
# ..                            ...
# 160                         0.270
# 161                         0.056
# 162                         0.091
# 163                         0.034
# 164                         0.167
#
# [165 rows x 41 columns]

# %%
df_all.dropna(how='any',inplace=True)
df_all
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 153            154.0            Rwanda     3.465            0.22208
# 154            155.0             Benin     3.340            0.28665
# 155            156.0             Syria     3.006            0.66320
# 156            157.0           Burundi     2.905            0.01530
# 157            158.0              Togo     2.839            0.20868
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# 1              1.40223                     0.94784
# 2              1.36058                     0.87464
# 3              1.33095                     0.88521
# 4              1.32261                     0.90563
# ..                 ...                         ...
# 153            0.77370                     0.42864
# 154            0.35386                     0.31910
# 155            0.47489                     0.72193
# 156            0.41587                     0.22396
# 157            0.13995                     0.28443
#
#      Freedom to make life choices_15  Generosity_15  \
# 0                            0.66557        0.29678
# 1                            0.62877        0.43630
# 2                            0.64938        0.34139
# 3                            0.66973        0.34699
# 4                            0.63297        0.45811
# ..                               ...            ...
# 153                          0.59201        0.22628
# 154                          0.48450        0.18260
# 155                          0.15684        0.47179
# 156                          0.11850        0.19727
# 157                          0.36453        0.16681
#
#      Perceptions of corruption_15  Overall rank_16  ...  Generosity_18  \
# 0                         0.41978              2.0  ...          0.256
# 1                         0.14145              3.0  ...          0.353
# 2                         0.48357              1.0  ...          0.284
# 3                         0.36503              4.0  ...          0.286
# 4                         0.32957              6.0  ...          0.321
# ..                            ...              ...  ...            ...
# 153                       0.55191            152.0  ...          0.200
# 154                       0.08010            153.0  ...          0.163
# 155                       0.18906            156.0  ...          0.376
# 156                       0.10062            157.0  ...          0.149
# 157                       0.10731            155.0  ...          0.158
#
#      Perceptions of corruption_18  Overall rank_19  Score_19  \
# 0                           0.357              6.0     7.480
# 1                           0.138              4.0     7.494
# 2                           0.408              2.0     7.600
# 3                           0.340              3.0     7.554
# 4                           0.291              9.0     7.278
# ..                            ...              ...       ...
# 153                         0.444            152.0     3.334
# 154                         0.067            102.0     4.883
# 155                         0.144            149.0     3.462
# 156                         0.076            145.0     3.775
# 157                         0.101            139.0     4.085
#
#      GDP per capita_19  Social support_19  Healthy life expectancy_19  \
# 0                1.452              1.526                       1.052
# 1                1.380              1.624                       1.026
# 2                1.383              1.573                       0.996
# 3                1.488              1.582                       1.028
# 4                1.365              1.505                       1.039
# ..                 ...                ...                         ...
# 153              0.359              0.711                       0.614
# 154              0.393              0.437                       0.397
# 155              0.619              0.378                       0.440
# 156              0.046              0.447                       0.380
# 157              0.275              0.572                       0.410
#
#      Freedom to make life choices_19  Generosity_19  \
# 0                              0.572          0.263
# 1                              0.591          0.354
# 2                              0.592          0.252
# 3                              0.603          0.271
# 4                              0.584          0.285
# ..                               ...            ...
# 153                            0.555          0.217
# 154                            0.349          0.175
# 155                            0.013          0.331
# 156                            0.220          0.176
# 157                            0.293          0.177
#
#      Perceptions of corruption_19
# 0                           0.343
# 1                           0.118
# 2                           0.410
# 3                           0.341
# 4                           0.308
# ..                            ...
# 153                         0.411
# 154                         0.082
# 155                         0.141
# 156                         0.180
# 157                         0.085
#
# [144 rows x 41 columns]

# %%
df_all.to_csv("world_happinesstam.csv", index=False, header=True)

# %%
df_all['average_happiness_score_all'] = df_all[['Score_15', 'Score_16','Score_17', 'Score_18','Score_19']].mean(axis=1)
df_all
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 153            154.0            Rwanda     3.465            0.22208
# 154            155.0             Benin     3.340            0.28665
# 155            156.0             Syria     3.006            0.66320
# 156            157.0           Burundi     2.905            0.01530
# 157            158.0              Togo     2.839            0.20868
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# 1              1.40223                     0.94784
# 2              1.36058                     0.87464
# 3              1.33095                     0.88521
# 4              1.32261                     0.90563
# ..                 ...                         ...
# 153            0.77370                     0.42864
# 154            0.35386                     0.31910
# 155            0.47489                     0.72193
# 156            0.41587                     0.22396
# 157            0.13995                     0.28443
#
#      Freedom to make life choices_15  Generosity_15  \
# 0                            0.66557        0.29678
# 1                            0.62877        0.43630
# 2                            0.64938        0.34139
# 3                            0.66973        0.34699
# 4                            0.63297        0.45811
# ..                               ...            ...
# 153                          0.59201        0.22628
# 154                          0.48450        0.18260
# 155                          0.15684        0.47179
# 156                          0.11850        0.19727
# 157                          0.36453        0.16681
#
#      Perceptions of corruption_15  Overall rank_16  ...  \
# 0                         0.41978              2.0  ...
# 1                         0.14145              3.0  ...
# 2                         0.48357              1.0  ...
# 3                         0.36503              4.0  ...
# 4                         0.32957              6.0  ...
# ..                            ...              ...  ...
# 153                       0.55191            152.0  ...
# 154                       0.08010            153.0  ...
# 155                       0.18906            156.0  ...
# 156                       0.10062            157.0  ...
# 157                       0.10731            155.0  ...
#
#      Perceptions of corruption_18  Overall rank_19  Score_19  \
# 0                           0.357              6.0     7.480
# 1                           0.138              4.0     7.494
# 2                           0.408              2.0     7.600
# 3                           0.340              3.0     7.554
# 4                           0.291              9.0     7.278
# ..                            ...              ...       ...
# 153                         0.444            152.0     3.334
# 154                         0.067            102.0     4.883
# 155                         0.144            149.0     3.462
# 156                         0.076            145.0     3.775
# 157                         0.101            139.0     4.085
#
#      GDP per capita_19  Social support_19  Healthy life expectancy_19  \
# 0                1.452              1.526                       1.052
# 1                1.380              1.624                       1.026
# 2                1.383              1.573                       0.996
# 3                1.488              1.582                       1.028
# 4                1.365              1.505                       1.039
# ..                 ...                ...                         ...
# 153              0.359              0.711                       0.614
# 154              0.393              0.437                       0.397
# 155              0.619              0.378                       0.440
# 156              0.046              0.447                       0.380
# 157              0.275              0.572                       0.410
#
#      Freedom to make life choices_19  Generosity_19  \
# 0                              0.572          0.263
# 1                              0.591          0.354
# 2                              0.592          0.252
# 3                              0.603          0.271
# 4                              0.584          0.285
# ..                               ...            ...
# 153                            0.555          0.217
# 154                            0.349          0.175
# 155                            0.013          0.331
# 156                            0.220          0.176
# 157                            0.293          0.177
#
#      Perceptions of corruption_19  average_happiness_score_all
# 0                           0.343                       7.5114
# 1                           0.118                       7.5110
# 2                           0.410                       7.5460
# 3                           0.341                       7.5410
# 4                           0.308                       7.3506
# ..                            ...                          ...
# 153                         0.411                       3.4386
# 154                         0.082                       3.9010
# 155                         0.141                       3.2922
# 156                         0.180                       3.0790
# 157                         0.085                       3.5442
#
# [144 rows x 42 columns]

# %%
df_all['average_rank_all'] = df_all[['Overall rank_15',
                                     'Overall rank_16',
                                     'Overall rank_17', 
                                     'Overall rank_18',
                                     'Overall rank_19']].mean(axis=1)

df_all['average_GDP_all'] = df_all[['GDP per capita_15',
                                     'GDP per capita_16',
                                     'GDP per capita_17', 
                                     'GDP per capita_18',
                                     'GDP per capita_19']].mean(axis=1)

df_all['average_social_all'] = df_all[['Social support_15',
                                     'Social support_16',
                                     'Social support_17', 
                                     'Social support_18',
                                     'Social support_19']].mean(axis=1)

df_all['average_health_all'] = df_all[['Healthy life expectancy_15',
                                     'Healthy life expectancy_16',
                                     'Healthy life expectancy_17', 
                                     'Healthy life expectancy_18',
                                     'Healthy life expectancy_19']].mean(axis=1)

df_all['average_freedom_all'] = df_all[['Freedom to make life choices_15',
                                     'Freedom to make life choices_16',
                                     'Freedom to make life choices_17', 
                                     'Freedom to make life choices_18',
                                     'Freedom to make life choices_19']].mean(axis=1)

df_all['average_generosity_all'] = df_all[['Generosity_15',
                                     'Generosity_16',
                                     'Generosity_17', 
                                     'Generosity_18',
                                     'Generosity_19']].mean(axis=1)

df_all['average_corruption_all'] = df_all[['Perceptions of corruption_15',
                                     'Perceptions of corruption_16',
                                     'Perceptions of corruption_17', 
                                     'Perceptions of corruption_18',
                                     'Perceptions of corruption_19']].mean(axis=1)
df_all
# Out:
#      Overall rank_15 Country or region  Score_15  GDP per capita_15  \
# 0                1.0       Switzerland     7.587            1.39651
# 1                2.0           Iceland     7.561            1.30232
# 2                3.0           Denmark     7.527            1.32548
# 3                4.0            Norway     7.522            1.45900
# 4                5.0            Canada     7.427            1.32629
# ..               ...               ...       ...                ...
# 153            154.0            Rwanda     3.465            0.22208
# 154            155.0             Benin     3.340            0.28665
# 155            156.0             Syria     3.006            0.66320
# 156            157.0           Burundi     2.905            0.01530
# 157            158.0              Togo     2.839            0.20868
#
#      Social support_15  Healthy life expectancy_15  \
# 0              1.34951                     0.94143
# 1              1.40223                     0.94784
# 2              1.36058                     0.87464
# 3              1.33095                     0.88521
# 4              1.32261                     0.90563
# ..                 ...                         ...
# 153            0.77370                     0.42864
# 154            0.35386                     0.31910
# 155            0.47489                     0.72193
# 156            0.41587                     0.22396
# 157            0.13995                     0.28443
#
#      Freedom to make life choices_15  Generosity_15  \
# 0                            0.66557        0.29678
# 1                            0.62877        0.43630
# 2                            0.64938        0.34139
# 3                            0.66973        0.34699
# 4                            0.63297        0.45811
# ..                               ...            ...
# 153                          0.59201        0.22628
# 154                          0.48450        0.18260
# 155                          0.15684        0.47179
# 156                          0.11850        0.19727
# 157                          0.36453        0.16681
#
#      Perceptions of corruption_15  Overall rank_16  ...  Generosity_19  \
# 0                         0.41978              2.0  ...          0.263
# 1                         0.14145              3.0  ...          0.354
# 2                         0.48357              1.0  ...          0.252
# 3                         0.36503              4.0  ...          0.271
# 4                         0.32957              6.0  ...          0.285
# ..                            ...              ...  ...            ...
# 153                       0.55191            152.0  ...          0.217
# 154                       0.08010            153.0  ...          0.175
# 155                       0.18906            156.0  ...          0.331
# 156                       0.10062            157.0  ...          0.176
# 157                       0.10731            155.0  ...          0.177
#
#      Perceptions of corruption_19  average_happiness_score_all  \
# 0                           0.343                       7.5114
# 1                           0.118                       7.5110
# 2                           0.410                       7.5460
# 3                           0.341                       7.5410
# 4                           0.308                       7.3506
# ..                            ...                          ...
# 153                         0.411                       3.4386
# 154                         0.082                       3.9010
# 155                         0.141                       3.2922
# 156                         0.180                       3.0790
# 157                         0.085                       3.5442
#
#      average_rank_all  average_GDP_all  average_social_all  \
# 0                 3.6         1.472164            1.417332
# 1                 3.2         1.386523            1.492813
# 2                 2.2         1.396729            1.447688
# 3                 2.8         1.519381            1.431075
# 4                 6.8         1.388129            1.387412
# ..                ...              ...                 ...
# 153             152.0         0.322057            0.788453
# 154             137.8         0.376745            0.340470
# 155             152.6         0.699109            0.355931
# 156             153.8         0.062447            0.470817
# 157             148.2         0.265871            0.323567
#
#      average_health_all  average_freedom_all  average_generosity_all  \
# 0              0.928318             0.620642                0.277432
# 1              0.917744             0.618035                0.419124
# 2              0.865249             0.625959                0.318876
# 3              0.873333             0.638049                0.328990
# 4              0.900558             0.610954                0.389598
# ..                  ...                  ...                     ...
# 153            0.417543             0.581611                0.226311
# 154            0.275262             0.419387                0.186070
# 155            0.566281             0.081700                0.431285
# 156            0.211608             0.101320                0.185921
# 157            0.288529             0.363747                0.174775
#
#      average_corruption_all
# 0                  0.379763
# 1                  0.140145
# 2                  0.429374
# 3                  0.343951
# 4                  0.305846
# ..                      ...
# 153                0.473468
# 154                0.071368
# 155                0.159547
# 156                0.106992
# 157                0.100969
#
# [144 rows x 49 columns]

# %%
df_all.to_csv("world_happinesstam.csv", index=False, header=True)

# %%
df_all.columns
# Out:
# Index(['Overall rank_15', 'Country or region', 'Score_15', 'GDP per capita_15',
#        'Social support_15', 'Healthy life expectancy_15',
#        'Freedom to make life choices_15', 'Generosity_15',
#        'Perceptions of corruption_15', 'Overall rank_16', 'Score_16',
#        'GDP per capita_16', 'Social support_16', 'Healthy life expectancy_16',
#        'Freedom to make life choices_16', 'Generosity_16',
#        'Perceptions of corruption_16', 'Overall rank_17', 'Score_17',
#        'GDP per capita_17', 'Social support_17', 'Healthy life expectancy_17',
#        'Freedom to make life choices_17', 'Generosity_17',
#        'Perceptions of corruption_17', 'Overall rank_18', 'Score_18',
#        'GDP per capita_18', 'Social support_18', 'Healthy life expectancy_18',
#        'Freedom to make life choices_18', 'Generosity_18',
#        'Perceptions of corruption_18', 'Overall rank_19', 'Score_19',
#        'GDP per capita_19', 'Social support_19', 'Healthy life expectancy_19',
#        'Freedom to make life choices_19', 'Generosity_19',
#        'Perceptions of corruption_19', 'average_happiness_score_all',
#        'average_rank_all', 'average_GDP_all', 'average_social_all',
#        'average_health_all', 'average_freedom_all', 'average_generosity_all',
#        'average_corruption_all'],
#       dtype='object')

# %%
df_allavgfree1 = df_all[['Country or region','average_happiness_score_all',
       'average_rank_all', 'average_GDP_all', 'average_social_all',
       'average_health_all', 'average_freedom_all', 'average_generosity_all',
       'average_corruption_all']].sort_values(by = 'average_rank_all',
            ascending = True).head(20)

# %%
df_allavgfree1
# Out:
#    Country or region  average_happiness_score_all  average_rank_all  \
# 2            Denmark                       7.5460               2.2
# 3             Norway                       7.5410               2.8
# 1            Iceland                       7.5110               3.2
# 0        Switzerland                       7.5114               3.6
# 5            Finland                       7.5378               3.6
# 6        Netherlands                       7.4046               6.2
# 4             Canada                       7.3506               6.8
# 8        New Zealand                       7.3130               8.2
# 7             Sweden                       7.3192               8.6
# 9          Australia                       7.2762              10.0
# 12           Austria                       7.1420              12.0
# 11        Costa Rica                       7.1262              12.6
# 10            Israel                       7.1422              13.0
# 14     United States                       6.9988              15.8
# 17           Ireland                       6.9644              16.4
# 16        Luxembourg                       6.9360              17.2
# 18           Belgium                       6.9214              17.6
# 20    United Kingdom                       6.9100              17.8
# 25           Germany                       6.9290              18.0
# 13            Mexico                       6.7252              21.4
#
#     average_GDP_all  average_social_all  average_health_all  \
# 2          1.396729            1.447688            0.865249
# 3          1.519381            1.431075            0.873333
# 1          1.386523            1.492813            0.917744
# 0          1.472164            1.417332            0.928318
# 5          1.356960            1.434429            0.873836
# 6          1.411013            1.349646            0.878569
# 4          1.388129            1.387412            0.900558
# 8          1.317509            1.439729            0.891618
# 7          1.403981            1.368574            0.898991
# 9          1.394885            1.409006            0.914529
# 12         1.398341            1.363963            0.883680
# 11         1.035655            1.315161            0.832248
# 10         1.303722            1.321918            0.902689
# 14         1.455946            1.328570            0.821615
# 17         1.460415            1.445056            0.878933
# 16         1.637675            1.343241            0.903490
# 18         1.375398            1.357493            0.882870
# 20         1.337567            1.367932            0.881735
# 25         1.395343            1.359526            0.870736
# 13         1.079361            1.082994            0.771570
#
#     average_freedom_all  average_generosity_all  average_corruption_all
# 2              0.625959                0.318876                0.429374
# 3              0.638049                0.328990                0.343951
# 1              0.618035                0.419124                0.140145
# 0              0.620642                0.277432                0.379763
# 5              0.621536                0.217783                0.398474
# 6              0.589651                0.415150                0.298614
# 4              0.610954                0.389598                0.305846
# 8              0.617782                0.432805                0.400015
# 7              0.617581                0.336512                0.397502
# 9              0.605043                0.416078                0.314573
# 12             0.576929                0.292400                0.214260
# 11             0.591228                0.196423                0.101081
# 10             0.417500                0.319937                0.120874
# 14             0.506882                0.355080                0.140844
# 17             0.572192                0.388300                0.299792
# 16             0.583832                0.245846                0.337421
# 18             0.538762                0.208881                0.237845
# 20             0.503760                0.424691                0.244018
# 25             0.558588                0.291386                0.265134
# 13             0.436726                0.104416                0.139489

# %%
df_allavgfree2 = df_all[['Country or region','average_happiness_score_all',
       'average_rank_all', 'average_GDP_all', 'average_social_all',
       'average_health_all', 'average_freedom_all', 'average_generosity_all',
       'average_corruption_all']].sort_values(by = 'average_rank_all',
            ascending = False).head(20)

# %%
df_allavgfree2
# Out:
#     Country or region  average_happiness_score_all  average_rank_all  \
# 156           Burundi                       3.0790             153.8
# 155             Syria                       3.2922             152.6
# 153            Rwanda                       3.4386             152.0
# 145          Tanzania                       3.4660             150.8
# 152       Afghanistan                       3.5128             149.4
# 157              Togo                       3.5442             148.2
# 135             Yemen                       3.6258             146.4
# 146        Madagascar                       3.7454             145.0
# 149            Guinea                       3.8536             141.6
# 115           Liberia                       3.8392             140.8
# 127          Botswana                       3.8300             140.2
# 130            Malawi                       3.8830             139.2
# 118             Haiti                       3.8656             139.0
# 148              Chad                       4.0034             138.6
# 140            Uganda                       4.0202             138.0
# 154             Benin                       3.9010             137.8
# 114          Zimbabwe                       4.0066             134.8
# 143             Niger                       4.1046             133.8
# 151      Burkina Faso                       4.0738             133.4
# 137              Mali                       4.2190             129.2
#
#      average_GDP_all  average_social_all  average_health_all  \
# 156         0.062447            0.470817            0.211608
# 155         0.699109            0.355931            0.566281
# 153         0.322057            0.788453            0.417543
# 145         0.439777            0.939380            0.396732
# 152         0.357113            0.409753            0.254707
# 157         0.265871            0.323567            0.288529
# 135         0.489313            0.865448            0.365440
# 146         0.265918            0.773236            0.434105
# 149         0.273374            0.637579            0.241702
# 115         0.089260            0.789066            0.302716
# 127         1.053581            1.107411            0.338407
# 130         0.142714            0.434382            0.327070
# 118         0.322862            0.616216            0.335746
# 148         0.382017            0.803851            0.094895
# 140         0.318728            1.066326            0.286499
# 154         0.376745            0.340470            0.275262
# 114         0.344051            1.007727            0.274403
# 143         0.126605            0.802395            0.282839
# 151         0.314660            0.935740            0.266813
# 137         0.360968            1.103613            0.199733
#
#      average_freedom_all  average_generosity_all  average_corruption_all
# 156             0.101320                0.185921                0.106992
# 155             0.081700                0.431285                0.159547
# 153             0.581611                0.226311                0.473468
# 145             0.386880                0.311749                0.083699
# 152             0.117924                0.267730                0.058094
# 157             0.363747                0.174775                0.100969
# 135             0.244175                0.096929                0.067045
# 146             0.177375                0.193293                0.062706
# 149             0.352274                0.248505                0.106306
# 115             0.332934                0.237960                0.042558
# 127             0.490607                0.079042                0.104603
# 130             0.457151                0.271226                0.077424
# 118             0.089268                0.448331                0.126076
# 148             0.177684                0.193129                0.058758
# 140             0.428597                0.279689                0.063032
# 154             0.419387                0.186070                0.071368
# 114             0.323257                0.169409                0.089997
# 143             0.385798                0.199049                0.133545
# 151             0.324000                0.212773                0.122996
# 137             0.332925                0.174795                0.094592

# %%
df_allavg = df_all[['Country or region','average_happiness_score_all',
       'average_rank_all', 'average_GDP_all', 'average_social_all',
       'average_health_all', 'average_freedom_all', 'average_generosity_all',
       'average_corruption_all']]

# %%
df_allavg
# Out:
#     Country or region  average_happiness_score_all  average_rank_all  \
# 0         Switzerland                       7.5114               3.6
# 1             Iceland                       7.5110               3.2
# 2             Denmark                       7.5460               2.2
# 3              Norway                       7.5410               2.8
# 4              Canada                       7.3506               6.8
# ..                ...                          ...               ...
# 153            Rwanda                       3.4386             152.0
# 154             Benin                       3.9010             137.8
# 155             Syria                       3.2922             152.6
# 156           Burundi                       3.0790             153.8
# 157              Togo                       3.5442             148.2
#
#      average_GDP_all  average_social_all  average_health_all  \
# 0           1.472164            1.417332            0.928318
# 1           1.386523            1.492813            0.917744
# 2           1.396729            1.447688            0.865249
# 3           1.519381            1.431075            0.873333
# 4           1.388129            1.387412            0.900558
# ..               ...                 ...                 ...
# 153         0.322057            0.788453            0.417543
# 154         0.376745            0.340470            0.275262
# 155         0.699109            0.355931            0.566281
# 156         0.062447            0.470817            0.211608
# 157         0.265871            0.323567            0.288529
#
#      average_freedom_all  average_generosity_all  average_corruption_all
# 0               0.620642                0.277432                0.379763
# 1               0.618035                0.419124                0.140145
# 2               0.625959                0.318876                0.429374
# 3               0.638049                0.328990                0.343951
# 4               0.610954                0.389598                0.305846
# ..                   ...                     ...                     ...
# 153             0.581611                0.226311                0.473468
# 154             0.419387                0.186070                0.071368
# 155             0.081700                0.431285                0.159547
# 156             0.101320                0.185921                0.106992
# 157             0.363747                0.174775                0.100969
#
# [144 rows x 9 columns]

# %%
plt.figure(figsize=(14,7))

plt.title("Happiness Score vs Healthy life expectancy")
sns.regplot(data=df_allavg, x='average_health_all', y='average_happiness_score_all');

# %%
plt.figure(figsize=(14,7))
plt.title("Top 10 Countries with Highest Healthy life expectancy")
sns.barplot(data = df_allavg.sort_values('average_health_all', ascending= False).head(10), x='Country or region', y='average_corruption_all')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(14,7))
plt.title("Top 10 Countries with Lowest Healthy life expectancy")
sns.barplot(data = df_allavg.sort_values('average_health_all', ascending= True).head(10), x='Country or region', y='average_corruption_all')
plt.xticks(rotation=90);

# %%
cols = df15new.columns
d15 = df15new.rename(columns={"Happiness Rank":"Overall rank",
                               "Country":"Country or region",
                               "Happiness Score":"Score",
                               "Economy (GDP per Capita)":"GDP per capita",
                               "Family":"Social support",
                               "Health (Life Expectancy)":"Healthy life expectancy",
                               "Freedom":"Freedom to make life choices",
                               "Generosity":"Generosity", 
                               "Trust (Government Corruption)": "Perceptions of corruption"})
df15new['year'] = 2015

cols = df16new.columns
d16 = df16new.rename(columns={"Happiness Rank":"Overall rank",
                               "Country":"Country or region",
                               "Happiness Score":"Score",
                               "Economy (GDP per Capita)":"GDP per capita",
                               "Family":"Social support",
                               "Health (Life Expectancy)":"Healthy life expectancy",
                               "Freedom":"Freedom to make life choices",
                               "Generosity":"Generosity", 
                               "Trust (Government Corruption)": "Perceptions of corruption"})
df16new['year'] = 2016

cols = df17new.columns
d17 = df17new.rename(columns={"Happiness Rank":"Overall rank",
                               "Country":"Country or region",
                               "Happiness Score":"Score",
                               "Economy (GDP per Capita)":"GDP per capita",
                               "Family":"Social support",
                               "Health (Life Expectancy)":"Healthy life expectancy",
                               "Freedom":"Freedom to make life choices",
                               "Generosity":"Generosity", 
                               "Trust (Government Corruption)": "Perceptions of corruption"})
df17new['year'] = 2017

cols = data_18.columns
d18 = data_18.rename(columns={"Happiness Rank":"Overall rank",
                               "Country":"Country or region",
                               "Happiness Score":"Score",
                               "Economy (GDP per Capita)":"GDP per capita",
                               "Family":"Social support",
                               "Health (Life Expectancy)":"Healthy life expectancy",
                               "Freedom":"Freedom to make life choices",
                               "Generosity":"Generosity", 
                               "Trust (Government Corruption)": "Perceptions of corruption"})
data_18['year'] = 2018

cols = data_19.columns
d19 = data_19.rename(columns={"Happiness Rank":"Overall rank",
                               "Country":"Country or region",
                               "Happiness Score":"Score",
                               "Economy (GDP per Capita)":"GDP per capita",
                               "Family":"Social support",
                               "Health (Life Expectancy)":"Healthy life expectancy",
                               "Freedom":"Freedom to make life choices",
                               "Generosity":"Generosity", 
                               "Trust (Government Corruption)": "Perceptions of corruption"})
data_19['year'] = 2019

# %%
features = ['year', 'Overall rank', 'Country or region', 'Score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']

# %%
all_year_data = pd.concat([d15[features], d16[features], d17[features], d18[features], d19[features]])

# %%
all_year_data
# Out:
#      year  Overall rank         Country or region  Score  GDP per capita  \
# 0    2015             1               Switzerland  7.587         1.39651
# 1    2015             2                   Iceland  7.561         1.30232
# 2    2015             3                   Denmark  7.527         1.32548
# 3    2015             4                    Norway  7.522         1.45900
# 4    2015             5                    Canada  7.427         1.32629
# ..    ...           ...                       ...    ...             ...
# 151  2019           152                    Rwanda  3.334         0.35900
# 152  2019           153                  Tanzania  3.231         0.47600
# 153  2019           154               Afghanistan  3.203         0.35000
# 154  2019           155  Central African Republic  3.083         0.02600
# 155  2019           156               South Sudan  2.853         0.30600
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.34951                  0.94143                       0.66557
# 1           1.40223                  0.94784                       0.62877
# 2           1.36058                  0.87464                       0.64938
# 3           1.33095                  0.88521                       0.66973
# 4           1.32261                  0.90563                       0.63297
# ..              ...                      ...                           ...
# 151         0.71100                  0.61400                       0.55500
# 152         0.88500                  0.49900                       0.41700
# 153         0.51700                  0.36100                       0.00000
# 154         0.00000                  0.10500                       0.22500
# 155         0.57500                  0.29500                       0.01000
#
#      Generosity  Perceptions of corruption
# 0       0.29678                    0.41978
# 1       0.43630                    0.14145
# 2       0.34139                    0.48357
# 3       0.34699                    0.36503
# 4       0.45811                    0.32957
# ..          ...                        ...
# 151     0.21700                    0.41100
# 152     0.27600                    0.14700
# 153     0.15800                    0.02500
# 154     0.23500                    0.03500
# 155     0.20200                    0.09100
#
# [782 rows x 10 columns]

# %%
df_allavg.columns
# Out:
# Index(['Country or region', 'average_happiness_score_all', 'average_rank_all',
#        'average_GDP_all', 'average_social_all', 'average_health_all',
#        'average_freedom_all', 'average_generosity_all',
#        'average_corruption_all'],
#       dtype='object')

# %%
plt.figure(figsize=(14,7))
plt.title("Top 10 Countries with High Happiness Score")
sns.barplot(data = df_allavg.sort_values('average_happiness_score_all', ascending= False).head(10), x='Country or region', y='average_happiness_score_all')
plt.xticks(rotation=90);

# %%
top_5_country = df_allavg.sort_values('average_happiness_score_all', ascending= False).head(5)['Country or region']
generosity_rank = [np.where(df_allavg.sort_values('average_generosity_all', ascending= False).reset_index()['Country or region']==i)[0][0] +1 for i in top_5_country]
gdp_rank = [np.where(df_allavg.sort_values('average_GDP_all', ascending= False).reset_index()['Country or region']==i)[0][0] +1 for i in top_5_country]
Social_Support_rank = [np.where(df_allavg.sort_values('average_social_all', ascending= False).reset_index()['Country or region']==i)[0][0] +1 for i in top_5_country]
Healthy_life_exp_rank = [np.where(df_allavg.sort_values('average_health_all', ascending= False).reset_index()['Country or region']==i)[0][0] +1 for i in top_5_country]
Freedom_choice__rank = [np.where(df_allavg.sort_values('average_freedom_all', ascending= False).reset_index()['Country or region']==i)[0][0] +1 for i in top_5_country]
Perce_corruption_rank = [np.where(df_allavg.sort_values('average_corruption_all', ascending= False).reset_index()['Country or region']==i)[0][0] +1 for i in top_5_country]

# %%
feature_rank_top_5_country = pd.DataFrame({
    'country':top_5_country,
    'Generosity_rank':generosity_rank,
    'GDP_rank':gdp_rank,
    'Social_Support_rank':Social_Support_rank,
    'Healthy_life_expectancy_rank':Healthy_life_exp_rank,
    'Freedom_make_choices_rank':Freedom_choice__rank,
    'Perceptions_of_corruption_rank':Perce_corruption_rank})

# %%
feature_rank_top_5_country
# Out:
#        country  Generosity_rank  GDP_rank  Social_Support_rank  \
# 2      Denmark               28        14                    2
# 3       Norway               25         5                    7
# 5      Finland               65        22                    5
# 0  Switzerland               39         6                    8
# 1      Iceland               10        19                    1
#
#    Healthy_life_expectancy_rank  Freedom_make_choices_rank  \
# 2                            29                          4
# 3                            26                          2
# 5                            25                          5
# 0                             7                          6
# 1                             8                          7
#
#    Perceptions_of_corruption_rank
# 2                               3
# 3                               9
# 5                               5
# 0                               7
# 1                              42

# %%
plt.figure(figsize=(15,7))
base_color = sns.color_palette()[0]
for i, col in enumerate(feature_rank_top_5_country.columns[1:]):
        plt.subplot(2,3,i+1)
        sns.barplot(data=feature_rank_top_5_country,y=col, x='country', color=base_color)
        plt.xticks(rotation=15)
